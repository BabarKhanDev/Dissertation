# %% [markdown]
# # Memorability Classifier
#
# #### Dataset: VISCHEMA PLUS
# #### Dataset image shape: (3x700x700)
# #### Dataset label shape: (3x700x700)
# #### Dataset label format:
# VMS map. It is a 3x700x700 image that is mostly black, the image outputted is a representation of the most memorable locations in the input.
#
# #### Model Plan
# I think a U-net would be best here. I will have to learn how to use skip connections.
#
# #### Loss function considerations:
# Maybe squared difference between every pixel in the expected output vs the predicted output. This might be computationally expensive.

# %%
# Import the required libraries

import torch
import os
import torchvision.datasets as datasets
from torch.utils.data import Dataset, DataLoader, random_split
from torchvision import transforms
from torch.nn.functional import interpolate
import torch.nn as nn
import math
import numpy as np
from natsort import natsorted
from PIL import Image

# %% [markdown]
# #### Dataclass and Dataloaders
# I need to create a custom dataclass because the labels are more complex than strings. I have called this VISCHEMA_PLUS. I tried to load all of the images into memory at initialisation but that caused my laptop to run out of memory. Instead I will load an image when it is called by the `__getitem__` method.

# %%
class VISCHEMA_PLUS(Dataset):
    def __init__(self, 
                 image_dir = 'VISCHEMA_PLUS/images', 
                 label_dir = 'VISCHEMA_PLUS/vms', 
                 class_dir='VISCHEMA_PLUS/vms_classified',
                 onehot_dir='VISCHEMA_PLUS/onehot_tensors',
                 transform = None):
        
        self.transform = transform
        
        self.image_dir  = image_dir
        self.label_dir  = label_dir
        self.class_dir  = class_dir
        self.onehot_dir = onehot_dir
        
        all_images = os.listdir(image_dir)
        self.all_images = natsorted(all_images)
        
    def __len__(self):
        return len(self.all_images)

    def __getitem__(self, idx):    
        
        convert_tensor = transforms.ToTensor()
        
        image = Image.open(f"{self.image_dir}/{self.all_images[idx]}").convert("RGB")
        image = convert_tensor(image)

        label = Image.open(f"{self.label_dir}/{self.all_images[idx]}").convert("RGB")
        label = convert_tensor(label)
        
        classified_label = Image.open(f"{self.class_dir}/{self.all_images[idx]}").convert("RGB")
        classified_label = convert_tensor(classified_label)
        
        #onehot_label = torch.load(f'{self.onehot_dir}/{self.all_images[idx][:-4]}.pt')
        if self.transform != None:
            image = self.transform(image)
            label = self.transform(label)
            classified_label = self.transform(classified_label)
        
        return image, label, classified_label#, onehot_label

# I have resized the images to 64x64 as this will make designing the model easier.
image_transforms = transforms.Compose([
    transforms.Resize(700),
    transforms.Normalize(0.5,0.5)
])
        
dataset = VISCHEMA_PLUS(transform = image_transforms)
train_size = int(0.8 * len(dataset))
test_size = len(dataset) - train_size
train_dataset, test_dataset = torch.utils.data.random_split(dataset, [train_size, test_size])

batch_size = 1
train_loader = DataLoader(dataset = train_dataset, batch_size = batch_size, shuffle=True)
test_loader = DataLoader(dataset = test_dataset, batch_size = batch_size, shuffle=True)

print(f'{len(train_dataset)} Items in Train dataset')
print(f'{len(test_dataset)}  Items in Test dataset')
# Out:
# 1280 Items in Train dataset
# 320  Items in Test dataset

# %% [markdown]
# #### Test that the images and labels look good

# %%
import matplotlib.pyplot as plt
from helpers import onehotToImage

figure = plt.figure(figsize=(15,15))
cols, rows = 4, 1
for i in range(rows):
    
    images, labels, classes, _ = next(iter(train_loader))
    
    figure.add_subplot(rows,cols, cols*i+1)
    plt.axis("off")
    plt.imshow((images[0,:].squeeze().permute(1, 2, 0) +1 )/2 )
    
    figure.add_subplot(rows,cols, cols*i+2)
    plt.axis("off")
    plt.imshow((labels[0,:].squeeze().permute(1, 2, 0) +1 )/2 )
    
    figure.add_subplot(rows,cols, cols*i+3)
    plt.axis("off")
    plt.imshow((classes[0,:].squeeze().permute(1, 2, 0) +1 )/2 )
    
    figure.add_subplot(rows,cols, cols*i+4)
    plt.axis("off")
    plt.imshow((onehotToImage(onehot[0,:]).squeeze().permute(1, 2, 0) +1 )/2 )

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5684\1900687375.py in <module>
#       6 for i in range(rows):
#       7
# ----> 8     images, labels, classes, _ = next(iter(train_loader))
#       9
#      10     figure.add_subplot(rows,cols, cols*i+1)
#
# ValueError: not enough values to unpack (expected 4, got 3)

# %% [markdown]
# #### Test if the code to convert from 11 channels to 3 works

# %%
import matplotlib.pyplot as plt
from helpers import onehotToImage

# Import the required libraries

import torch
import os
import torchvision.datasets as datasets
from torch.utils.data import Dataset, DataLoader, random_split
from torchvision import transforms
from torch.nn.functional import interpolate
import torch.nn as nn
import math
import numpy as np
from natsort import natsorted
from PIL import Image

figure = plt.figure(figsize=(15,15))
cols, rows = 1, 1

filename = 'sun_aaajuldidvlcyzhv'

onehot =  torch.load(f'VISCHEMA_PLUS/onehot_tensors/{filename}.pt')
convert_tensor = transforms.ToTensor()

image = Image.open(f'VISCHEMA_PLUS/images/{filename}.jpg').convert("RGB")
image = convert_tensor(image)

label = Image.open(f'VISCHEMA_PLUS/vms/{filename}.jpg').convert("RGB")
label = convert_tensor(label)

classified_label = Image.open(f'VISCHEMA_PLUS/vms_classified/{filename}.jpg').convert("RGB")
classified_label = convert_tensor(classified_label)

for i in range(1):
    
    figure.add_subplot(1,4,1)
    plt.axis("off")
    plt.imshow(image.squeeze().permute(1, 2, 0)  )
    
    figure.add_subplot(1,4,2)
    plt.axis("off")
    plt.imshow(label.squeeze().permute(1, 2, 0)  )
    
    figure.add_subplot(1,4,3)
    plt.axis("off")
    plt.imshow(classified_label.squeeze().permute(1, 2, 0) )
    
    figure.add_subplot(1,4,4)
    plt.axis("off")
    plt.imshow(onehotToImage(onehot.long()).squeeze().permute(1, 2, 0) )

plt.tight_layout()
plt.show()
# Out:
# tensor(0) tensor(1)
# tensor(0) tensor(1)
# torch.Size([3, 700, 700])
# tensor(0) tensor(255)
# tensor(0) tensor(204)
# tensor(0) tensor(255)
# tensor(0.) tensor(1.)

# %% [markdown]
# #### Creating Models
# There isn't a lot of data so maybe transfer learning would be a better idea but first I want to make my own models so that I can at least track some improvement.
#
# I want to automatically test a range of models and train them all with various hyperparameters. I will create a range of models, a function that returns an instanciated copy of each model in a list, loop over that list along with all of the hyperparameters that I want to tune, and save the results in a `.txt` file.

# %% [markdown]
# ## Classic UNet

# %%
class Block(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.main = nn.Sequential(
            nn.Conv2d(in_channels,out_channels,3),
            nn.ReLU(),
            nn.Conv2d(out_channels,out_channels,3),
            nn.ReLU(),
        )
    def forward(self, x):
        return self.main(x)
    
class Encoder(nn.Module):
    def __init__(self, channels=(3,64,128,256,512)):
        super().__init__()
        self.encoding_blocks = nn.ModuleList(
            [Block(channels[i], channels[i+1]) for i in range(len(channels)-1)]
        )
        self.pool = nn.MaxPool2d(2)
    
    def forward(self, x):
        features = []
        
        for block in self.encoding_blocks:
            x = block(x)
            features.append(x)
            x = self.pool(x)
                 
        return features
        
class Decoder(nn.Module):
    def __init__(self, channels=(512, 256, 128, 64)):
        super().__init__()
        self.channels = channels
        self.upconvs = nn.ModuleList([nn.ConvTranspose2d(self.channels[i], self.channels[i+1],2,2) for i in range(len(channels)-1)])
        self.decoder_blocks = nn.ModuleList(
            [Block(channels[i], channels[i+1]) for i in range(len(channels)-1)]
        )
    
    def forward(self, x, encoder_features):
        for i in range(len(self.channels)-1):
            x = self.upconvs[i](x)
            features = self.crop(encoder_features[i], x)
            x = torch.cat([x, features], dim=1)
            x = self.decoder_blocks[i](x)
        return x
    
    def crop(self, features, x):
        _, _, height, width = x.shape
        features = transforms.CenterCrop([height, width])(features)
        return features
        
class UNet(nn.Module):
    def __init__(self, 
                 encode_channels=(3,128,256,512), 
                 decode_channels=(512, 256, 128), 
                 num_class=3, 
                 retain_dim=True, 
                 output_size=(572,572)):
        
        super(UNet, self).__init__()
        
        self.encoder = Encoder(encode_channels)
        self.decoder = Decoder(decode_channels)
        
        self.head = nn.Conv2d(decode_channels[-1], num_class, 1)
        self.retain_dim = retain_dim
        self.output_size = output_size
        
        # Initialize weights
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                nn.init.xavier_uniform_(m.weight)
                if m.bias is not None:
                    nn.init.constant_(m.bias, 0)
            elif isinstance(m, nn.ConvTranspose2d):
                nn.init.xavier_uniform_(m.weight)
                if m.bias is not None:
                    nn.init.constant_(m.bias, 0)


    def forward(self, x):
        
        encoding_features = self.encoder(x)
        decoding_features = self.decoder(encoding_features[::-1][0], encoding_features[::-1][1:])
        output = self.head(decoding_features)
        
        if self.retain_dim:
            output = interpolate(output, self.output_size)
        
        output = torch.clamp(output, -1,1)
        return output

images, _ = next(iter(train_loader))
_ , _ , height, width = images.shape
model = UNet(retain_dim=True, output_size=(height,width))

total_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print(f'{total_params} Parameters in UNet')

output = model(images)
print(output.shape)
# Out:
# 7445123 Parameters in UNet
# torch.Size([4, 3, 64, 64])

# %% [markdown]
# ### This code will:
# 1. loop through all labels in the dataset
# 2. Create a segmentation map of them
# 3. Save them to the disk

# %%
from torchvision.utils import save_image

# This expects an image tensor that:
# Has a range of [0,255]
# Has a shape of (3,n,n)

# Outputs a 3xnxn image with range [0,255] where only the largest sub-pixels remain and have been rounded down to the closest 51
def label_segmentation(label):
    
    # Creates a 1 channel tensor with the maximum values across all 3 channels
    max_val, _ = torch.max(label, dim=0)
    
    # Creates a new 3xnxn tensor where the original label only remains if it was the biggest
    label = torch.where(torch.eq(label, max_val.unsqueeze(0)), label, torch.zeros_like(label))
    
    # Any values between [1,51) are rounded up to 51
    label = torch.where((label > 0) & (label<51), torch.ones_like(label)*51, label)
    
    # Round the values down to the closest 51
    label = (label // 51)
    label = label.long()
    
    return label


"""for i, d in enumerate(os.listdir('VISCHEMA_PLUS/vms')):
    label = Image.open(f"VISCHEMA_PLUS/vms/{d}").convert("RGB")
    label = transforms.ToTensor()(label)
    label[2] *= 0
    label *= 255
    
    label = label_segmentation(label)
    label /= 255
        
    save_image(label,f"VISCHEMA_PLUS/vms_classified/{d}" )
    
print('images segmented')"""
# Out:
# 'for i, d in enumerate(os.listdir(\'VISCHEMA_PLUS/vms\')):\n    label = Image.open(f"VISCHEMA_PLUS/vms/{d}").convert("RGB")\n    label = transforms.ToTensor()(label)\n    label[2] *= 0\n    label *= 255\n    \n    label = label_segmentation(label)\n    label /= 255\n        \n    save_image(label,f"VISCHEMA_PLUS/vms_classified/{d}" )\n    \nprint(\'images segmented\')'

# %% [markdown]
# ### This code will:
# 1. load all segmented images
# 2. convert them into 11 deep tensors
# 3. save the tensors into memory

# %%
def onehot_encode(tensor):
    
    tensor[1] += 6
    output = torch.zeros((11, 700, 700))

    # Loop through red channel spread these across output[0:5)
    indices = torch.nonzero(tensor[0] > 0)
    for j,k in indices:
        output[tensor[0][j][k] -1][j][k] = 1
    
    # Loop through green channel spread these across output[6:11)
    indices = torch.nonzero(tensor[1] > 6)
    for j,k in indices:
        output[tensor[1][j][k] -1][j][k] = 1

    # If red and green pixel are black then set output[5] = 1
    indices = torch.nonzero((tensor[0] == 0) & (tensor[1] == 6))
    for j,k in indices:
        output[5][j][k] = 1

    return output


print('Starting Image Classification')
for i, d in enumerate(os.listdir('VISCHEMA_PLUS/vms')):
    
    # Skip any that we have computed already
    if not (f'{d[:-4]}.pt' in os.listdir('VISCHEMA_PLUS/onehot_tensors')):
        
        
        if i%10 == 0:
            print(f'[{i}/1600] images completed')

        label = Image.open(f"VISCHEMA_PLUS/vms/{d}").convert("RGB")
        label = transforms.ToTensor()(label)

        label[2] *= 0
        label *= 255
        label = label.long()
        label = label_segmentation(label)

        # This will return an 11 channel tensor with one hot encoding for where the pixels go
        label = onehot_encode(label)

        torch.save(label, f"VISCHEMA_PLUS/onehot_tensors/{d[:-4]}.pt")


print('All Images Classified')
# Out:
# Starting Image Classification
# [0/1600] images completed
# [10/1600] images completed
# [20/1600] images completed
# [30/1600] images completed
# [40/1600] images completed
# [50/1600] images completed
# [60/1600] images completed
# [70/1600] images completed
# [80/1600] images completed
# [90/1600] images completed
# [100/1600] images completed
# [110/1600] images completed

# %%
for _,d in enumerate(os.listdir('VISCHEMA_PLUS/vms')):
    if f'{d[:-4]}.pt' in os.listdir('VISCHEMA_PLUS/onehot_tensors'):
        print(f'found {d}')

print("done")
# Out:
# found sun_aaajuldidvlcyzhv.jpg
# found sun_aabjtppsnozdurdt.jpg
# found sun_aadakyricvbjhamx.jpg
# found sun_aaebjpeispxohmfv.jpg
# found sun_aaeggavxrhahhhsp.jpg
# found sun_aaenwecffknbumjq.jpg
# found sun_aaexpnawiehinlpy.jpg
# found sun_aaggckrhlbnenekd.jpg
# found sun_aahzjzgqsstcdpnq.jpg
# found sun_aajsfnjsaqdunpdp.jpg
# found sun_aajuvjmbeoyrydac.jpg
# found sun_aakrykgxfqjyunvq.jpg
# found sun_aaktvzxuzcrholrn.jpg
# found sun_aalrsaxeqqthtwnd.jpg
# found sun_aalvhwdpyoipnzzy.jpg
# found sun_aamdtqvmzkmjgivi.jpg
# found sun_aamidmlrrdfdnbgl.jpg
# found sun_aaofphpvkeqlhwgu.jpg
# found sun_aaotjvucbfgmtzjj.jpg
# found sun_aaovkqlsvacznbgr.jpg
# found sun_aaovtbniyzpboymw.jpg
# found sun_aaphkzwyhkodgwey.jpg
# found sun_aapyhvdueagtxhar.jpg
# found sun_aaqvvjdycgpjbdzq.jpg
# found sun_aarjxwdguluuhwzu.jpg
# found sun_aarrcygkwuzaeiuk.jpg
# found sun_aarzwginlqrfnzvf.jpg
# found sun_aasawwrseapigucx.jpg
# found sun_aaslbwtcdcwjukuo.jpg
# found sun_aasothdstfehplzt.jpg
# ...

# %% [markdown]
# ## Lets see what the default outputs look like
# <i> I expect this to be noise <i>

# %%
import matplotlib.pyplot as plt

images, labels = next(iter(train_loader))
figure = plt.figure(figsize=(15,15))
output = model(images)

ideal = np.add(images, labels) 

cols, rows = 2, 4
for i in range(rows):
    figure.add_subplot(rows,cols, cols*i+1)
    plt.axis("off")
    plt.imshow(((ideal[i,:]*0.5).cpu().detach().squeeze().permute(1, 2, 0) +1 )/ 2 )
    figure.add_subplot(rows,cols, cols*i+2)
    plt.axis("off")
    plt.imshow((output[i,:].cpu().detach().squeeze().permute(1, 2, 0) +1 )/ 2 )  
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Test what images look like with the VMS applied ontop of it

# %%
# Set up our training environment
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

images, _ = next(iter(train_loader))
_ , _ , height, width = images.shape
model = UNet(retain_dim=True, output_size=(height,width))
model = model.to(device)

# initialize loss function and optimizer
def dice_loss(pred, target, weights = [1,2,1]):
    
    pred, target = (pred+1)/2, (target+1)/2
    
    weights = torch.tensor(weights).to(device)
    weights = weights.view(1,3,1,1)
    weights = weights.expand_as(pred)
    
    pred = pred * weights
    pred = pred.view(-1)
    target = target * weights
    target = target.view(-1)
    
    intersection = (pred * target).sum()
    denominator = torch.clamp(pred.sum() + target.sum(), min=1e-15)
    loss = (1 - (2. * intersection) / denominator)

    return loss

# Not sure if reduction should be none, mean, or sum.
# Test all 3?
loss_func = nn.L1Loss(reduction = 'sum')

optim = torch.optim.Adam(model.parameters(), lr=0.001)
num_epochs = 40

# These variables will store the data for analysis
training_losses = []
test_losses = []

# %%
images, labels = next(iter(train_loader))
images, labels = images.to(device), labels.to(device)
output = model(images)
loss = loss_func(output,labels)
print(loss)
# Out:
# tensor(693517.5000, grad_fn=<SumBackward0>)

# %%
print('Starting Training')

for epoch in range(num_epochs):
    
    # Go into training mode
    model.train()
    
    # Train the model and evaluate on the training set
    total_train_loss = 0
    total_test_loss = 0

    for i, (images, labels) in enumerate(train_loader):
    
        # Move images to device and create an image prediction
        images, labels = images.to(device), labels.to(device)
        goals = np.sum(images, labels)/2
        # This is the composition of the image and the vms, which we want the network to create
        
        output = model(images)
    
        #Evaluate the loss of our model and take a step
        loss = loss_func(output,goals)
        optim.zero_grad()
        loss.backward()
        optim.step()

        total_train_loss += loss*images.shape[0]
        torch.cuda.empty_cache()

    total_train_loss /= len(train_dataset)
    training_losses.append(total_train_loss.to("cpu"))

    # Evaluate the model on the test set
    # Reset counters and switch to eval mode
    model.eval()

    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)
            output = model(images)
            loss = loss_func(output,labels)
            total_test_loss += loss*images.shape[0]

        total_test_loss /= len(test_dataset)

    # save counters
    test_losses.append(total_test_loss.item()) 
    
    print(f'Epoch [{epoch + 1}],Train Loss: {total_train_loss}, Test Loss: {total_test_loss}')
# Out:
# Starting Training
# Epoch [1],Train Loss: -4.321983814239502, Test Loss: -4.348073482513428
# Epoch [2],Train Loss: -4.331298351287842, Test Loss: -4.348073482513428
# Epoch [3],Train Loss: -4.331298351287842, Test Loss: -4.3480730056762695
# Epoch [4],Train Loss: -4.331297397613525, Test Loss: -4.348073482513428
# Epoch [5],Train Loss: -4.331297874450684, Test Loss: -4.3480730056762695
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22124\1671645064.py in <module>
#      18         #Move images to device and create an image prediction
#      19         images, labels = images.to(device), labels.to(device)
# ---> 20         output = model(images)
#      21
#      22         #Evaluate the loss of our model and take a step
#
# ~\anaconda3\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
# ...

# %%
plt.title("Training curve")

print(training_losses)
print(test_losses)
plt.plot(range(len(training_losses)),training_losses,'r')
plt.plot(range(len(test_losses)),test_losses,'g')
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.show()
# Out:
# [tensor(-4.3220, grad_fn=<ToCopyBackward0>), tensor(-4.3313, grad_fn=<ToCopyBackward0>), tensor(-4.3313, grad_fn=<ToCopyBackward0>), tensor(-4.3313, grad_fn=<ToCopyBackward0>), tensor(-4.3313, grad_fn=<ToCopyBackward0>)]
# [-4.348073482513428, -4.348073482513428, -4.3480730056762695, -4.348073482513428, -4.3480730056762695]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22124\3718640305.py in <module>
#       3 print(training_losses)
#       4 print(test_losses)
# ----> 5 plt.plot(range(len(training_losses)),training_losses,'r')
#       6 plt.plot(range(len(test_losses)),test_losses,'g')
#       7 plt.xlabel("Epoch")
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2767 @_copy_docstring_and_deprecators(Axes.plot)
#    2768 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# ...

# %%
torch.save(model.state_dict(), 'weights.pkl')

# %%
import matplotlib.pyplot as plt

images, labels = next(iter(train_loader))
images, labels = images.to(device), labels.to(device)
figure = plt.figure(figsize=(15,15))
output = model(images)
cols, rows = 1, 4
for i in range(cols * rows):
    figure.add_subplot(rows,cols*3, 3*i+1)
    plt.axis("off")
    plt.imshow((images[i,:].cpu().detach().squeeze().permute(1, 2, 0) +1 )/2 )
    figure.add_subplot(rows,cols*3, 3*i+2)
    plt.axis("off")
    plt.imshow((labels[i,:].cpu().detach().squeeze().permute(1, 2, 0) +1 )/2 )
    figure.add_subplot(rows,cols*3, 3*i+3)
    plt.axis("off")
    plt.imshow((output[i,:].cpu().detach().squeeze().permute(1, 2, 0) +1 )/2 )
    
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22124\4006167435.py in <module>
#       9     figure.add_subplot(rows,cols*3, 3*i+1)
#      10     plt.axis("off")
# ---> 11     plt.imshow((images[i,:].cpu().detach().squeeze().permute(1, 2, 0) +1 )/2 )
#      12     figure.add_subplot(rows,cols*3, 3*i+2)
#      13     plt.axis("off")
#
# IndexError: index 4 is out of bounds for dimension 0 with size 4
